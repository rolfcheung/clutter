# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
# read data
data = pd.read_csv('../data/ordered_data_2.csv')
data = data[['Province', 'City', 'Category', 'year', 'coal', 'oil', 'gas', 'process']]
data.head()
# Out:
#   Province    City  Category  year   coal   oil   gas  process
# 0       河南  Anyang         1  2000    NaN   NaN   NaN      NaN
# 1       河南  Anyang         1  2001  40.60  0.50  0.45     0.85
# 2       河南  Anyang         1  2002    NaN   NaN   NaN      NaN
# 3       河南  Anyang         1  2003  42.90  0.48  0.60     0.78
# 4       河南  Anyang         1  2004  48.82  0.68  0.66     0.51

# %%
data_ind = data[['City','year', 'coal', 'oil', 'gas', 'process']]

data_ind = data_ind.set_index(['City', 'year'])
data_ind.head()
# Out:
#               coal   oil   gas  process
# City   year
# Anyang 2000    NaN   NaN   NaN      NaN
#        2001  40.60  0.50  0.45     0.85
#        2002    NaN   NaN   NaN      NaN
#        2003  42.90  0.48  0.60     0.78
#        2004  48.82  0.68  0.66     0.51

# %%
fig = plt.figure(figsize=(40,60))


x = 0.05
y = 0.9
fontsize = 40
fontweight = 'heavy'
width = 0.83
yticks_fontsize = 30

#
ax1 = fig.add_subplot(8,4,1)
data_ind.xs('Anyang').plot.bar(stacked = True, ax = ax1,legend=False, width=width)
plt.text(x, y,'Anyang', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax1.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax1.set_xlabel('')

# 
ax2 = fig.add_subplot(8,4,2)
data_ind.xs('Hebi').plot.bar(stacked = True, ax = ax2,legend=False, width=width)
plt.text(x, y,'Hebi', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax2.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax2.set_xlabel('')

#
ax3 = fig.add_subplot(8,4,3)
data_ind.xs('Zhumadian').plot.bar(stacked = True, ax = ax3,legend=False, width=width)

plt.text(x, y,'Zhumadian', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax3.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax3.set_xlabel('')

#
ax4 = fig.add_subplot(8,4,4)
data_ind.xs('Zhoukou').plot.bar(stacked = True, ax = ax4,legend=False, width=width)
plt.text(x, y,'Zhoukou', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax4.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax4.set_xlabel('')

#
ax5 = fig.add_subplot(8,4,5)
data_ind.xs('Handan').plot.bar(stacked = True, ax = ax5,legend=False, width=width)
plt.text(x, y,'Handan', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax5.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax5.set_xlabel('')


#
ax6 = fig.add_subplot(8,4,6)
data_ind.xs('Jincheng').plot.bar(stacked = True, ax = ax6,legend=False, width=width)
plt.text(x, y,'Jincheng', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax6.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax6.set_xlabel('')


#
ax7 = fig.add_subplot(8,4,7)
data_ind.xs('Yuncheng').plot.bar(stacked = True, ax = ax7,legend=False, width=width)
plt.text(x, y,'Yuncheng', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax7.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax7.set_xlabel('')


#
ax8 = fig.add_subplot(8,4,8)
data_ind.xs('Jiyuan').plot.bar(stacked = True, ax = ax8,legend=False, width=width)
plt.text(x, y,'Jiyuan', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax8.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax8.set_xlabel('')


#
ax9 = fig.add_subplot(8,4,9)
data_ind.xs('Kaifeng').plot.bar(stacked = True, ax = ax9,legend=False, width=width)
plt.text(x, y,'Kaifeng', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax9.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax9.set_xlabel('')


#
ax10 = fig.add_subplot(8,4,10)
data_ind.xs('Sanmenxia').plot.bar(stacked = True, ax = ax10,legend=False, width=width)
plt.text(x, y,'Sanmenxia', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax10.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax10.set_xlabel('')


#
ax11 = fig.add_subplot(8,4,11)
data_ind.xs('Shangqiu').plot.bar(stacked = True, ax = ax11,legend=False, width=width)
plt.text(x, y,'Shangqiu', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax11.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax11.set_xlabel('')


#
ax12 = fig.add_subplot(8,4,12)
data_ind.xs('Bengbu').plot.bar(stacked = True, ax = ax12,legend=False, width=width)
plt.text(x, y,'Bengbu', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax12.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax12.set_xlabel('')


#
ax13 = fig.add_subplot(8,4,13)
data_ind.xs('Huaibei').plot.bar(stacked = True, ax = ax13,legend=False, width=width)
plt.text(x, y,'Huaibei', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax13.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax13.set_xlabel('')


#
ax14 = fig.add_subplot(8,4,14)
data_ind.xs('Suzhou').plot.bar(stacked = True, ax = ax14,legend=False, width=width)
plt.text(x, y,'Suzhou', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax14.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax14.set_xlabel('')


#
ax15 = fig.add_subplot(8,4,15)
data_ind.xs('Heze').plot.bar(stacked = True, ax = ax15,legend=False, width=width)
plt.text(x, y,'Heze', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax15.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax15.set_xlabel('')


#
ax16 = fig.add_subplot(8,4,16)
data_ind.xs('Liaocheng').plot.bar(stacked = True, ax = ax16,legend=False, width=width)
plt.text(x, y,'Liaocheng', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax16.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax16.set_xlabel('')


#
ax17 = fig.add_subplot(8,4,17)
data_ind.xs('Jiaozuo').plot.bar(stacked = True, ax = ax17,legend=False, width=width)
plt.text(x, y,'Jiaozuo', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax17.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax17.set_xlabel('')


#
ax18 = fig.add_subplot(8,4,18)
data_ind.xs('Luoyang').plot.bar(stacked = True, ax = ax18,legend=False, width=width)
plt.text(x, y,'Luoyang', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax18.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax18.set_xlabel('')


#
ax19 = fig.add_subplot(8,4,19)
data_ind.xs('Nanyang').plot.bar(stacked = True, ax = ax19,legend=False, width=width)
plt.text(x, y,'Nanyang', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax19.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax19.set_xlabel('')


#
ax20 = fig.add_subplot(8,4,20)
data_ind.xs('Pingdingshan').plot.bar(stacked = True, ax = ax20,legend=False, width=width)
plt.text(x, y,'Pingdingshan', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax20.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax20.set_xlabel('')


#
ax21 = fig.add_subplot(8,4,21)
data_ind.xs('Xinyang').plot.bar(stacked = True, ax = ax21,legend=False, width=width)
plt.text(x, y,'Xinyang', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax21.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax21.set_xlabel('')



#
ax22 = fig.add_subplot(8,4,22)
data_ind.xs('Xuchang').plot.bar(stacked = True, ax = ax22,legend=False, width=width)
plt.text(x, y,'Xuchang', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax22.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax22.set_xlabel('')


#
ax23 = fig.add_subplot(8,4,23)
data_ind.xs('Zhengzhou').plot.bar(stacked = True, ax = ax23,legend=False, width=width)
plt.text(x, y,'Zhengzhou', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax23.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax23.set_xlabel('')


#
ax24 = fig.add_subplot(8,4,24)
data_ind.xs('Bozhou').plot.bar(stacked = True, ax = ax24,legend=False, width=width)
plt.text(x, y,'Bozhou', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax24.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax24.set_xlabel('')


#
ax25 = fig.add_subplot(8,4,25)
data_ind.xs('Xingtai').plot.bar(stacked = True, ax = ax25,legend=False, width=width)
plt.text(x, y,'Xingtai', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax25.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax25.set_xlabel('')


#
ax26 = fig.add_subplot(8,4,26)
data_ind.xs('Changzhi').plot.bar(stacked = True, ax = ax26,legend=False, width=width)
plt.text(x, y,'Changzhi', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax26.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax26.set_xlabel('')



#
ax27 = fig.add_subplot(8,4,27)
data_ind.xs('Puyang').plot.bar(stacked = True, ax = ax27,legend=False, width=width)
plt.text(x, y,'Puyang', 
         {'color': '#984ea3', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax27.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax27.set_xlabel('')


#
ax28 = fig.add_subplot(8,4,28)
data_ind.xs('Xinxiang').plot.bar(stacked = True, ax = ax28,legend=False, width=width)
plt.text(x, y,'Xinxiang', 
         {'color': '#984ea3', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax28.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax28.set_xlabel('')


#
ax29 = fig.add_subplot(8,4,29)
data_ind.xs('Fuyang').plot.bar(stacked = True, ax = ax29,legend=False, width=width)
plt.text(x, y,'Fuyang', 
         {'color': '#984ea3', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax29.transAxes)
plt.yticks(fontsize=yticks_fontsize)
plt.xticks(())
ax29.set_xlabel('')


handles, labels = ax1.get_legend_handles_labels()


fig.legend(handles, labels, ncol=4,
           prop={'size': 40},
           bbox_to_anchor=(0.7, 0.1))

fig.text(0.325, 0.06,'Anyang: 7 cities with a trend of abrupt fluctuation', 
         {'color': '#d7191c', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.05,'Jiyuan: 9 cities with a trend of steady upward', 
         {'color': '#377eb8', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.04,'Jiaozuo: 10 cities with a trend of rising at first and decreasing then', 
         {'color': '#4daf4a', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.03,'Puyang: 3 cities with a trend of relative stability', 
         {'color': '#984ea3', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.02,'Time span: 2000--2015', 
         {'fontsize': fontsize, 'name': 'Times New Roman'})



fig.tight_layout()

plt.savefig('../result/carbon_emission_years.svg',dpi=400, alpha=True)
plt.show()
