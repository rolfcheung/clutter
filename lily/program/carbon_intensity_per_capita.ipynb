# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# import packages
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from matplotlib.ticker import MaxNLocator, NullFormatter

# %%
# read data
data = pd.read_csv('../data/carbon_intensity_per_captia.csv', index_col=0)

data
# Out:
#         Anyang      Hebi  Zhoukou  Zhumadian   Handan  Jincheng  Yuncheng  \
# 2000       NaN       NaN      NaN        NaN  12.6905       NaN       NaN
# 2001   8.12360       NaN      NaN        NaN  14.0457       NaN       NaN
# 2002       NaN       NaN  1.35365        NaN  15.5515       NaN       NaN
# 2003   8.46166       NaN  0.73861        NaN  16.4615   9.22407       NaN
# 2004   9.53936   6.12145      NaN        NaN  12.9849  12.93960       NaN
# 2005       NaN       NaN  1.76295        NaN  12.7523  14.31090       NaN
# 2006       NaN  17.67440  1.37986        NaN  13.9320  31.83300   18.8972
# 2007  16.10660  20.99960  1.56400    2.19331  13.9961  34.06550   15.1032
# 2008  16.12490  26.79660  1.45676    2.63392  13.4133  30.41910   17.7470
# 2009  17.36680  28.76430  1.59950    2.52468  13.1308  34.33190   19.1105
# 2010       NaN  24.48530  1.44769    2.49818  12.7175  22.69180   14.9493
# 2011  14.70500  25.91720  1.50169    3.54988  16.1586  33.98210       NaN
# ...

# %%
city_name = list(data.head(0))

# %%
fig = plt.figure(figsize=(40,60))

x = 0.05
y = 0.9
fontsize = 40
fontweight = 'heavy'
width = 0.83
yticks_fontsize = 30

for i in range(0, 7):
    subset = data.iloc[:,i]
    ax = fig.add_subplot(8, 4, i+1)
    subset.plot.bar(ax = ax, 
                    legend=False,
                    color ='#ca0020',
                    width = 0.83)

#   Force integer axis labels on Matplotlib
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    
    plt.text(x, y,city_name[i], 
         {'color': '#ca0020', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax.transAxes)
    plt.yticks(fontsize=yticks_fontsize)
    plt.xticks(())
    
    
for i in range(7, 16):
    subset = data.iloc[:,i]
    ax = fig.add_subplot(8, 4, i+1)
    subset.plot.bar(ax = ax, 
                    legend=False,
                    color ='#f4a582',
                    width = 0.83)
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    plt.text(x, y,city_name[i], 
         {'color': '#f4a582', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax.transAxes)
    plt.yticks(fontsize=yticks_fontsize)
    plt.xticks(())
    

for i in range(16, 26):
    subset = data.iloc[:,i]
    ax = fig.add_subplot(8, 4, i+1)
    subset.plot.bar(ax = ax, 
                    legend=False,
                    color ='#35978f',
                    width = 0.83)
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    plt.text(x, y,city_name[i], 
         {'color': '#35978f', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax.transAxes)
    plt.yticks(fontsize=yticks_fontsize)
    plt.xticks(())
    
    
for i in range(26, 28):
    subset = data.iloc[:,i]
    ax = fig.add_subplot(8, 4, i+1)
    subset.plot.bar(ax = ax, 
                    legend=False,
                    color ='#0571b0',
                    width = 0.83)
#     ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    plt.text(x, y,city_name[i], 
         {'color': '#0571b0', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax.transAxes)
    plt.yticks(fontsize=yticks_fontsize)
    plt.xticks(())
    

ax29 = fig.add_subplot(8,4,29)
data.Fuyang.plot.bar(stacked = True, ax = ax29,color='#0571b0',legend=False, width=width)
plt.text(x, y,city_name[28], 
         {'color': '#984ea3', 'fontsize': fontsize, 'name': 'Times New Roman'},
         transform=ax29.transAxes)
yticks = [0, 1, 2]
ticklabels = ['0','1', '2']
plt.yticks(yticks, ticklabels, fontsize=yticks_fontsize)
# plt.gca().yaxis.set_minor_formatter(NullFormatter())

plt.xticks(())
ax29.set_xlabel('')
    
    
    
fig.text(0.325, 0.06,'Anyang: 7 cities with a trend of abrupt fluctuation', 
         {'color': '#ca0020', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.05,'Jiyuan: 9 cities with a trend of steady upward', 
         {'color': '#f4a582', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.04,'Jiaozuo: 10 cities with a trend of rising at first and decreasing then', 
         {'color': '#35978f', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.03,'Puyang: 3 cities with a trend of relative stability', 
         {'color': '#0571b0', 'fontsize': fontsize, 'name': 'Times New Roman'})

fig.text(0.325, 0.02,'Time span: 2000--2015', 
         {'fontsize': fontsize, 'name': 'Times New Roman'})



fig.tight_layout()



fig.tight_layout()

plt.savefig('../result/carbon_intensity_per_capita.eps',dpi=400, alpha=True)
plt.show()
